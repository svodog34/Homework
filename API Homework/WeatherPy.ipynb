# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
api_key="7e363e575760bcdb1ce6b9216de1b28a"

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 598

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#url
url = "http://api.openweathermap.org/data/2.5/weather?"

query_url = f"{url}appid={api_key}&units=imperial&q="

# %%
#run a test to see data and [u]
test3 = requests.get(query_url + 'New York').json()
test3
#gotta dig into dic
#response['name']
#response['clouds']['all']
#response['sys']['country']
#response['dt']
#response['main']['temp']
#response['coord']['lon']
#response['coord']['lat']
#response['main']['temp_max']
#response['wind']['speed']
# Out:
# {'coord': {'lon': -73.99, 'lat': 40.73},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 80.24,
#   'pressure': 1016,
#   'humidity': 65,
#   'temp_min': 75.99,
#   'temp_max': 84.2},
#  'visibility': 16093,
#  'wind': {'speed': 6.93, 'deg': 210},
#  'clouds': {'all': 75},
#  'dt': 1563335792,
#  'sys': {'type': 1,
#   'id': 4026,
#   'message': 0.015,
#   'country': 'US',
#   'sunrise': 1563269879,
#   'sunset': 1563323136},
#  'timezone': -14400,
#  'id': 5128581,
#  'name': 'New York',
#  'cod': 200}

# %%
weather_df = pd.DataFrame({'City' : cities})
weather_df['Cloudiness'] = ''
weather_df['Country'] = ''
weather_df['Date'] = ''
weather_df['Humidity'] = ''
weather_df['Lat'] = ''
weather_df['Lng'] = ''
weather_df['Max Speed'] = ''
weather_df['Wind Speed'] = ''
weather_df['Temp (F)'] = ''
row_count = 0
weather_df.head()
# Out:
#           City Cloudiness Country Date Humidity Lat Lng Max Speed Wind Speed  \
# 0  kjollefjord
# 1  broken hill
# 2    cape town
# 3     hermanus
# 4       atuona
#
#   Temp (F)
# 0
# 1
# 2
# 3
# 4

# %%
print('Executing Data Retrieval')
for index, row in weather_df.iterrows():
    city = row['City']
    response = requests.get(query_url + city).json()
    
    if response["cod"] == "404":
        print('City is not good... skip...')
        weather_df.loc[index, 'Country'] = 'Drop'
    else: 

        print(f' Processing Record {row_count} for {city}')

        weather_df.loc[index, 'Cloudiness'] = float(response['clouds']['all'])
        weather_df.loc[index, 'Country'] = (response['sys']['country'])
        weather_df.loc[index, 'Date'] = response['dt']
        weather_df.loc[index, 'Humidity'] = float(response['main']['humidity'])
        weather_df.loc[index, 'Lat'] = float(response['coord']['lat'])
        weather_df.loc[index, 'Lng'] = float(response['coord']['lon'])
        weather_df.loc[index, 'Max Speed'] = float(response['main']['temp_max'])
        weather_df.loc[index, 'Wind Speed'] = float(response['wind']['speed'])
        weather_df.loc[index, 'Temp (F)'] = float(response["main"]["temp"])
        row_count = row_count + 1
#        weather_df[weather_df.name != city]
#        row_count = row_count + 1
# Out:
# Executing Data Retrieval
#  Processing Record 0 for kjollefjord
#  Processing Record 1 for broken hill
#  Processing Record 2 for cape town
#  Processing Record 3 for hermanus
#  Processing Record 4 for atuona
# City is not good... skip...
#  Processing Record 5 for cidreira
#  Processing Record 6 for phan thiet
#  Processing Record 7 for butaritari
#  Processing Record 8 for cherskiy
#  Processing Record 9 for avarua
#  Processing Record 10 for punta arenas
# City is not good... skip...
#  Processing Record 11 for taybad
# City is not good... skip...
#  Processing Record 12 for port hardy
#  Processing Record 13 for rikitea
#  Processing Record 14 for soyo
#  Processing Record 15 for tasiilaq
#  Processing Record 469 for luorong
#  Processing Record 470 for makhu
#  Processing Record 471 for windhoek
#  Processing Record 472 for touros
#  Processing Record 473 for rudnogorsk
#  Processing Record 474 for hami
#  Processing Record 475 for nanzhang
#  Processing Record 476 for zimovniki
#  Processing Record 477 for menongue
#  Processing Record 478 for vardo
#  Processing Record 479 for markova
#  Processing Record 480 for campbeltown
#  Processing Record 481 for winnemucca
#  Processing Record 482 for tabou
#  Processing Record 483 for karatau
#  Processing Record 484 for gamboula
#  Processing Record 485 for guane
#  Processing Record 486 for necochea
#  Processing Record 487 for moree
#  Processing Record 488 for karoi
#  Processing Record 489 for fort morgan
#  Processing Record 490 for bondo
#  Processing Record 491 for krasnyy yar
#  Processing Record 492 for floro
#  Processing Record 493 for ouesso
#  Processing Record 494 for pathein
#  Processing Record 495 for cortez
#  Processing Record 496 for charters towers
#  Processing Record 497 for medea
#  Processing Record 498 for lipin bor
#  Processing Record 499 for yumen
#  Processing Record 500 for atyashevo
#  Processing Record 501 for mizdah
#  Processing Record 502 for rabat
#  Processing Record 503 for yabrud
#  Processing Record 504 for grand gaube
#  Processing Record 505 for merauke
# City is not good... skip...
#  Processing Record 506 for troitsko-pechorsk
# City is not good... skip...
#  Processing Record 507 for rodrigues alves
#  Processing Record 508 for saryozek
#  Processing Record 509 for cuauhtemoc
#  Processing Record 510 for vagur
#  Processing Record 511 for chekhov
#  Processing Record 512 for xiaoweizhai
# City is not good... skip...
#  Processing Record 513 for moussoro
#  Processing Record 514 for jumla
#  Processing Record 515 for najran
#  Processing Record 516 for krasnogorsk
#  Processing Record 517 for mitu
#  Processing Record 518 for sangamner
#  Processing Record 519 for monastyrshchina
#  Processing Record 520 for pachino
#  Processing Record 521 for gravdal
#  Processing Record 522 for morehead
#  Processing Record 523 for witu
#  Processing Record 524 for salta
# City is not good... skip...
#  Processing Record 525 for stony plain
#  Processing Record 526 for santa ines
#  Processing Record 527 for guadalajara
#  Processing Record 528 for little current
#  Processing Record 529 for corinto
#  Processing Record 530 for yamada
#  Processing Record 531 for aksha
#  Processing Record 532 for las vegas
#  Processing Record 533 for rio gallegos
#  Processing Record 534 for matagami
# City is not good... skip...
#  Processing Record 535 for orotukan

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df =  weather_df[weather_df.Country != 'Drop']

# %%
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 536 entries, 0 to 597
# Data columns (total 10 columns):
# City          536 non-null object
# Cloudiness    536 non-null object
# Country       536 non-null object
# Date          536 non-null object
# Humidity      536 non-null object
# Lat           536 non-null object
# Lng           536 non-null object
# Max Speed     536 non-null object
# Wind Speed    536 non-null object
# Temp (F)      536 non-null object
# dtypes: object(10)
# memory usage: 46.1+ KB

# %%
weather_df
# Out:
#                           City Cloudiness Country        Date Humidity    Lat  \
# 0                  kjollefjord         75      NO  1563336073       93  70.95
# 1                  broken hill         40      AU  1563336073       58 -31.97
# 2                    cape town         75      ZA  1563336073       87 -33.93
# 3                     hermanus         93      ZA  1563336074       95 -34.42
# 4                       atuona         27      PF  1563335543       77   -9.8
# 6                     cidreira          5      BR  1563336074       96 -30.17
# 7                   phan thiet        100      VN  1563336074       87  10.93
# 8                   butaritari        100      KI  1563336075       61   3.07
# 9     161.3     46.04       8.23    46.04
# 10  -159.78      73.4      14.99     73.4
# 11   -70.91      33.8       6.93     33.4
# 13    60.78     86.36       15.7    86.36
# 15  -127.42      64.4       8.05     64.4
# 16  -134.97     72.32       8.39    72.32
# 17    12.37     71.06       8.72    71.06
# 18   -37.64      44.6        4.7     44.6
# 20     6.27     70.16       3.42    70.16
# 21   142.36     84.74       8.77    84.74
# 22   115.24      89.6       5.82    87.89
# 23    -28.7      70.7       7.65     70.7
# 24    -51.1      48.2        4.7     48.2
# 25  -101.59     84.56      11.39    84.56
# 26   158.65      75.2      13.42     75.2
# 27   115.35     69.01       16.8     65.3
# 28   116.85      76.1      25.08     76.1
# 29    74.49      73.4       6.93     73.4
# 30   124.29     84.99          3    84.99
# 31    147.9     41.36      10.65    41.36
# 32   135.99      82.4       8.05     82.4
# 34    -90.4     83.12       21.9    83.12
# ..      ...       ...        ...      ...
# 564   56.19     50.18      11.68    50.18
# 566  -72.65      71.6       2.68     71.6
# 567   77.98     84.38       6.91    84.38
# 568 -111.63        90       8.01    88.29
# 569   -6.81      50.9      16.58     50.9
# 570   37.45      60.8       4.47    59.18
# 571  107.51     77.18       6.85    77.18
# 573   16.49     86.72       3.27    86.72
# 574   82.18     62.96       2.37    62.96
# 575   44.22      89.6       9.17     89.6
# 576   37.34      60.8       8.95    59.16
# 577   46.09      62.6       2.91     62.6
# 578    74.2     74.12       5.68    74.12
# 579   31.84     52.52       4.74    52.52
# 580   15.09      64.4       3.36    62.51
# 581    5.78        54       1.12    52.93
# 582  -83.43        79       6.93     75.4
# 583   40.44      69.8       6.58     69.8
# 584  -65.41        59       2.24    56.68
# 586    -114      62.6        4.7    60.19
# 587  -78.63      48.2       3.36     48.2
# 588   -3.16      75.2       3.36     73.4
# 589  -81.93      73.4       8.05    68.81
# 590  -76.26      71.6       6.93     71.6
# 591  137.08     87.01      10.29    82.98
# 592  113.29      77.9       7.96     77.9
# 593 -115.15       102       5.82    97.56
# 594  -69.22      32.9      10.27     32.9
# 595     8.4     67.64       2.64    67.64
# 597  151.67     62.06       4.94    62.06
#
# [536 rows x 10 columns]

# %%
weather_df.to_csv("Weather_Data.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Temp (F)"],
            edgecolor="orange", linewidths=1, marker="o", alpha=0.8, label="City")

# Titles
plt.title(f"City Lat vs. Max Temperature")
plt.ylabel("Max Temp (F)")
plt.xlabel("Latitude")
plt.grid(True)

#save figure
plt.savefig("Lat_Temp.png")

# Show
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Humidity"],
            edgecolor="green", linewidths=1, marker="o", alpha=0.8, label="City")

# Titles
plt.title(f"City Lat vs. Humidity")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)

#save figure
plt.savefig("Lat_Humidity.png")

# Show
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"],
            edgecolor="red", linewidths=1, marker="o", alpha=0.8, label="City")

# Titles
plt.title(f"City Lat vs. Cloudiness")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

#save figure
plt.savefig("Lat_Cloudiness.png")

# Show
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"],
            edgecolor="blue", linewidths=1, marker="o", alpha=0.8, label="City")

# Titles
plt.title(f"City Lat vs. Wind Speed")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)

#save figure
plt.savefig("Lat_Wind.png")

# Show
plt.show()
